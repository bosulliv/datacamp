# %%
?read.table
# Out:
# read.table                package:utils                R Documentation
#
# t
#
# n:
#
#      Reads a file in table format and creates a data frame from it,
#      with cases corresponding to lines and variables to fields in the
#      file.
#
# e:
#
#      read.table(file, header = FALSE, sep = "", quote = "\"'",
#                 dec = ".", numerals = c("allow.loss", "warn.loss", "no.loss"),
#                 row.names, col.names, as.is = !stringsAsFactors,
#                 na.strings = "NA", colClasses = NA, nrows = -1,
#                 skip = 0, check.names = TRUE, fill = !blank.lines.skip,
#                 strip.white = FALSE, blank.lines.skip = TRUE,
#                 comment.char = "#",
#                 allowEscapes = FALSE, flush = FALSE,
#                 stringsAsFactors = default.stringsAsFactors(),
#                 fileEncoding = "", encoding = "unknown", text, skipNul = FALSE)
#
#      read.csv(file, header = TRUE, sep = ",", quote = "\"",
# ...

# %%
?read_tsv
# Out:
# No documentation for ‘read_tsv’ in specified packages and libraries:
# you could try ‘??read_tsv’

# %%
library(readr)

# %%
?read_tsv
# Out:
# read_delim                package:readr                R Documentation
#
# e
#
# n:
#
#      ‘read_csv()’ and ‘read_tsv()’ are special cases of the general
#      ‘read_delim()’. They're useful for reading the most common types
#      of flat file data, comma separated values and tab separated
#      values, respectively. ‘read_csv2()’ uses ‘;’ for separators,
#      instead of ‘,’. This is common in European countries which use ‘,’
#      as the decimal separator.
#
# e:
#
#      read_delim(file, delim, quote = "\"", escape_backslash = FALSE,
#        escape_double = TRUE, col_names = TRUE, col_types = NULL,
#        locale = default_locale(), na = c("", "NA"), quoted_na = TRUE,
#        comment = "", trim_ws = FALSE, skip = 0, n_max = Inf,
#        guess_max = min(1000, n_max), progress = show_progress())
#
#      read_csv(file, col_names = TRUE, col_types = NULL,
#        locale = default_locale(), na = c("", "NA"), quoted_na = TRUE,
# ...

# %%
install.packages("gdata")
library(gdata)
# Out:
# also installing the dependency ‘gtools’
#
# Warning message in install.packages("gdata"):
# “installation of package ‘gtools’ had non-zero exit status”Warning message in install.packages("gdata"):
# “installation of package ‘gdata’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Error in library(gdata): there is no package called ‘gdata’
# Traceback:
#
# 1. library(gdata)
# 2. stop(txt, domain = NA)

# %%
install.packages("gtools")
# Out:
# Warning message in install.packages("gtools"):
# “installation of package ‘gtools’ had non-zero exit status”Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("XLConnect")
library(XLConnect)
# Out:
# also installing the dependency ‘XLConnectJars’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Loading required package: XLConnectJars
# XLConnect 0.2-13 by Mirai Solutions GmbH [aut],
#   Martin Studer [cre],
#   The Apache Software Foundation [ctb, cph] (Apache POI),
#   Graph Builder [ctb, cph] (Curvesapi Java library)
# http://www.mirai-solutions.com ,
# http://miraisolutions.wordpress.com

# %%
library(foreign)

# %%
?read.spss
# Out:
# read.spss               package:foreign                R Documentation
#
# e
#
# n:
#
#      ‘read.spss’ reads a file stored by the SPSS ‘save’ or ‘export’
#      commands.
#
#      This was orignally written in 2000 and has limited support for
#      changes in SPSS formats since (which have not been many).
#
# e:
#
#      read.spss(file, use.value.labels = TRUE, to.data.frame = FALSE,
#                max.value.labels = Inf, trim.factor.names = FALSE,
#                trim_values = TRUE, reencode = NA, use.missings = to.data.frame,
#                sub = ".", add.undeclared.levels = c("sort", "append", "no"),
#                duplicated.value.labels = c("append", "condense"),
#                duplicated.value.labels.infix = "_duplicated_", ...)
#
# s:
#
#     file: character string: the name of the file or URL to read.
#
# use.value.labels: logical: convert variables with value labels into R
#           factors with those levels?  This is only done if there are at
# ...
